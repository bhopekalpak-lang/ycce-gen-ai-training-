# %% [markdown]
# <a href="https://colab.research.google.com/github/bhopekalpak-lang/ycce-gen-ai-training-/blob/main/kalpak.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
if 'google.colab' in sys.modules:
  # !pip install --quiet langchain-community
# Data loading first step
from langchain_community.document_loaders import TextLoader
loadder = TextLoader("lignine.txt", encoding="utf-8")
loadder

# %%
text_documents = loadder.load()
text_documents
# Out:
# [Document(metadata={'source': 'lignine.txt'}, page_content='1.INTRODUCTION 1.1 Background  Lignocellulosic biomass is not the keyword that is being used in the sustainability circles, Lignocellulosic biomass is the foundation of the green energy revolution that is to come. Consider: starchy agricultural waste, such as rice husks and wheat straw and sugarcane bagasse; wood waste such as logging or construction sites; or specific energy crops, such as switchgrass or maiden grass. These sources are rich, they are renewable and most importantly, they are carbon-neutral in the right hands. Biomass is a recycled carbon previously taken into the atmosphere by plants unlike fossil fuels which release the old carbon that was in the atmosphere through pumping. In India alone, where more than 40 percent of the labour force is engaged in agriculture, we produce some 500 million tons of crop residues every year, most of it burned in the open air, and adding to air pollution and lost opportunities. The bioenergy initiative has gone on a rampage over the past few decades. The world is rapidly increasing energy demand, it has been projected that by the year 2050, the world will need to cut down by half, and the climate change is holding us to the task of reducing emissions. Introduce biofuels: ethanol, biodiesel, biogas, each of them based on the biomass feedstock. The hike here lies however, when lignocellulose is not that simple to pick. It is a hard nut whose three divorced polymers are cellulose (40-50, the sugarrich backbone), hemicellulose (20-35, the branched supporter) and lignin (15-30, the rigid glue that cannot be broken down). This is a structure that has developed in plants to avoid microbes and insects hence this is a strong hold against industrial processing. This is the point at which high-tech locksmiths like advanced sensing come in. The NIRS has become a game changer. NIRS works within 780-2500 nm range of wavelength and illuminate’s samples using near-infrared light and records the light that is reflected or transmitted. The waste is transformed into an engineered fuel source which opens the door to sustainable bioenergy that will be able to fuel homes and automobiles as well as industries without the carbon hangover. Operating on scales which have small difference of cellulose crystallinity or lignin content can create or destroy products, bioreactors are the bubbling vats on which microbes are fed biomass and produce fuels.  2 1.2 Motivation for the Study  The main aim of this research is to improve the utilization of renewable resources such as plant biomass while reducing negative environmental impacts. At this time, many industries depend heavily on fossil fuels, which contribute to greenhouse gas emissions and environmental pollution. At the same time, large amounts of lignin produced from agricultural and industrial activities are either discarded or burned rather.  While it can be converted into useful products or energy. Developing a rapid and better efficient method for analyzing plant materials could help industries identify better ways to reuse biomass and select suitable materials and pretreatment methods. A simple and effective monitoring system would also benefit  small to small rural industries as well as large industrial facilities by enabling them to process biomass in a more economical and efficient manner. 1.3 Significance of the Study  This study is important for several reasons. From an environmental perspective, it promotes sustainable development and reduces waste generation. It also promotes the development of new biomaterial products such as adhesives, composites and biodegradable materials. From an academic perspective, the study contributes to knowledge related to the use of sensor technologies for biomass analysis and degradation monitoring. This knowledge can support the development of smart bioreactors and other advanced waste-to-resource systems. When implemented effectively, such monitoring ...

# %%
# Text slitter
from langchain_text_splitters import RecursiveCharacterTextSplitter
textSplitter = RecursiveCharacterTextSplitter(chunk_size=200, chunk_overlap=20)
finalDocuments = textSplitter.split_documents(text_documents)
finalDocuments
# Out:
# [Document(metadata={'source': 'lignine.txt'}, page_content='1.INTRODUCTION 1.1 Background  Lignocellulosic biomass is not the keyword that is being used in the sustainability circles, Lignocellulosic biomass is the foundation of the green energy revolution'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='energy revolution that is to come. Consider: starchy agricultural waste, such as rice husks and wheat straw and sugarcane bagasse; wood waste such as logging or construction sites; or specific energy'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='or specific energy crops, such as switchgrass or maiden grass. These sources are rich, they are renewable and most importantly, they are carbon-neutral in the right hands. Biomass is a recycled'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='is a recycled carbon previously taken into the atmosphere by plants unlike fossil fuels which release the old carbon that was in the atmosphere through pumping. In India alone, where more than 40'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='where more than 40 percent of the labour force is engaged in agriculture, we produce some 500 million tons of crop residues every year, most of it burned in the open air, and adding to air pollution'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='to air pollution and lost opportunities. The bioenergy initiative has gone on a rampage over the past few decades. The world is rapidly increasing energy demand, it has been projected that by the'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='that by the year 2050, the world will need to cut down by half, and the climate change is holding us to the task of reducing emissions. Introduce biofuels: ethanol, biodiesel, biogas, each of them'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='each of them based on the biomass feedstock. The hike here lies however, when lignocellulose is not that simple to pick. It is a hard nut whose three divorced polymers are cellulose (40-50, the'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='(40-50, the sugarrich backbone), hemicellulose (20-35, the branched supporter) and lignin (15-30, the rigid glue that cannot be broken down). This is a structure that has developed in plants to avoid'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='in plants to avoid microbes and insects hence this is a strong hold against industrial processing. This is the point at which high-tech locksmiths like advanced sensing come in. The NIRS has become a'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='NIRS has become a game changer. NIRS works within 780-2500 nm range of wavelength and illuminate’s samples using near-infrared light and records the light that is reflected or transmitted. The waste'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='The waste is transformed into an engineered fuel source which opens the door to sustainable bioenergy that will be able to fuel homes and automobiles as well as industries without the carbon'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='without the carbon hangover. Operating on scales which have small difference of cellulose crystallinity or lignin content can create or destroy products, bioreactors are the bubbling vats on which'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='vats on which microbes are fed biomass and produce fuels.  2 1.2 Motivation for the Study  The main aim of this research is to improve the utilization of renewable resources such as plant biomass'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='as plant biomass while reducing negative environmental impacts. At this time, many industries depend heavily on fossil fuels, which contribute to greenhouse gas emissions and environmental pollution.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='pollution. At the same time, large amounts of lignin produced from agricultural and industrial activities are either discarded or burned rather.  While it can be converted into useful products or'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='useful products or energy. Developing a rapid and better efficient method for analyzing plant materials could help industries identify better ways to reuse biomass and select suitable materials and'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='materials and pretreatment methods. A simple and effective monitoring system would also benefit  small to small rural industries as well as large industrial facilities by enabling them to process'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='them to process biomass in a more economical and efficient manner. 1.3 Significance of the Study  This study is important for several reasons. From an environmental perspective, it promotes'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='it promotes sustainable development and reduces waste generation. It also promotes the development of new biomaterial products such as adhesives, composites and biodegradable materials. From an'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='materials. From an academic perspective, the study contributes to knowledge related to the use of sensor technologies for biomass analysis and degradation monitoring. This knowledge can support the'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='can support the development of smart bioreactors and other advanced waste-to-resource systems. When implemented effectively, such monitoring systems can reduce reliance on nonrenewable resources and'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='resources and help address the growing problem of agricultural waste management. 3 1.4 Problem Statement  Although bioreactor designs have improved over time, challenges still remain in the efficient'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='in the efficient degradation of plant materials. Plant biomass varies widely in composition and structural characteristics. Currently, most systems lack real-time monitoring, making it difficult to'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='it difficult to maintain optimal environmental conditions for microorganisms responsible for biomass degradation. As a result, the efficiency of biomass degradation, gas production and overall'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and overall processing time can be negatively affected. Therefore, there is a need for a system capable of measuring biomass characteristics and monitoring the degradation process in real time while'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='in real time while providing feedback for improved process control. 1.5 Aim and Objectives  The purpose of this study is to develop a sensor-based system to measure the properties of plant residues'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of plant residues and monitor their degradation. The main objectives are as follow: • To develop method that helps to determine plant characteristics of their residue that influence the degradation.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='the degradation. • To develop sensor that should be multi-capable of monitoring components like  Cellulose, lignin, hemicellulose. • To integrate monitoring system with Internet of Things technology.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Things technology. • For deeper understanding of impact of onsite monitoring data on basis on bioreactor application. 1.6 Scope of the Study  The scope of this study focuses on sensor-based'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='on sensor-based monitoring of biomass degradation inside a bioreactor. The research involves analyzing plant samples, placing sensors 4 within the reactor, and linking sensor data to reactor'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='data to reactor performance. The experiments are conducted at laboratory and pilot scales rather than full industrial scale. The main objective is to develop and demonstrate a process and methodology'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and methodology that could later be scaled up for industrial applications. 1.7 Research Questions  The real time problem faced are guide by this research: 1. How can the degradation of plant biomass'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of plant biomass be effectively measured? 2. How does the composition of plant biomass influence degradation? 3. Can real-time measurements be used to improve control of bioreactors? 4. How can this'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='4. How can this system support future? 1.8 Major Contributions   The main contributions of this work include:  • Design and demonstration of sensor network that helps in monitoring degradation of'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='degradation of plant biomasses. • Development of an IoT- based data logging system. • Experimental demonstration that shows improved degradation through monitoring. • Establishment of correlations'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of correlations among the biomass chemicals composition and degradation.  1.9 Organization of the Thesis  The remaining chapters are organized as follows. Chapter 2 reviews previous work related to'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='work related to biomass characterization and sensor-based bioreactor monitoring.  Chapter 3 explains the system design, the working principles, and the experimental approach.  Chapter 4 presents the'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='4 presents the results and discusses system performance.  Chapter 5 summarizes the findings, offers conclusions, and suggests avenues for future research.  Chapter 6 provides supporting material and'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='material and appendices.  5 CHAPTER – 2 REVIEW OF LITERATURE 6 2. REVIEW OF LITERATURE 2.1 Overview Agricultural waste is becoming more efficient as the demand for biofuels as well as bioproduct is'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='as bioproduct is continuously increasing. However, there are significant obstacles because they come from a wide variety of sources and takes a long time to decompose, making it more difficult to use'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='difficult to use as a resource. Biomass straws, primarily from crops including rice, corn, wheat, and rapeseed, were employed as study materials.  "Lignocellulosic material," a naturally occurring'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='naturally occurring mixture of cellulose, hemicellulose, and lignin, makes up the majority of plant material. These components give plants their strength and structure, and they also influence how'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='also influence how quickly living organisms may break down the material. Due of its speed, near infrared spectroscopy (NIR) is employed in numerous fields. No additional ingredients, chemicals, or'),
#  Document(metadata={'source': 'lignine.txt'}, page_content="chemicals, or specific preparation are required. It doesn't produce any garbage either.  First-generation biomass is derived from food crops; second-generation biomass is derived from lignocellulosic"),
#  Document(metadata={'source': 'lignine.txt'}, page_content='lignocellulosic materials; and third- and fourth-generation biomass is derived from microalgae. One ample and renewable resource derived from plants is lignocellulosic biomass. Growing and processing'),
#  Document(metadata={'source': 'lignine.txt'}, page_content="and processing agricultural products such as fruits, vegetables, meat, fowl, milk products, and crops results in agricultural wastes. Figure 1, depicts India's annual production of agricultural"),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of agricultural waste.  Depending on the kind of agricultural product, these wastes can be solid, liquid, or a thick mixture. Fossil fuels are becoming more and more necessary as development'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='as development advances. However, excessive usage of these finite fuels has led to an energy crisis. Climate change, contaminated air, and other environmental concerns are also brought about by it.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='about by it. There are two types of procedures for analysing lignocellulose: chemical methods and instrumental methods. Chemical procedures are less accurate than instrumental techniques like gas'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='techniques like gas chromatography (GC) and excellent-performance liquid chromatography (HPLC). 7 Figure 2.1 Yearly agriculture waste production in India (Report on State of Indian Agriculture'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Indian Agriculture 2015–16). 2.2 Methodology Fernández et al. checked the chemical composition of lignocellulosic biomass using Near Infrared Spectroscopy (NIRS), a rapid and non-destructive'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and non-destructive technique. Before conducting the spectrum measurements, they gathered the biomass samples, let them to dry, then crushed them until the particles were all the same size. The NIR'),
#  Document(metadata={'source': 'lignine.txt'}, page_content="same size. The NIR spectra were collected within a specific range of wavelengths to identify the absorption patterns associated with the biomass's O–H, C–H, and N–H groups. To increase the efficiency"),
#  Document(metadata={'source': 'lignine.txt'}, page_content='the efficiency of NIRS models they carried chemical tests on lignin, cellulose, hemicellulose, moisture. Partial Least Squares Regression (PLSR) method was used to find correlations between spectral'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='between spectral information and chemical values. To enhance the reliability of predictions, scatter correction and normalization methods were employed as preprocessing tools to eliminate error in'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='eliminate error in spectral information. The performance of the models was determined by using statistical measures which includes the coefficient of determination (R²) and prediction error values.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='error values. The results showed that Near Infrared Spectroscopy (NIRS) is an efficient method for predicting various components and moisture content in lignocellulosic materials. Thus, making this'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Thus, making this method efficient for bioreactor and bioreactor applications [1]. Zhao et al. created model based on NIRS to measure lignocellulosic components in crop residues. The samples that'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='The samples that used by Zhao et al. were obtained from different agricultural sources. The obtained sources were dried and ground it to uniform size particles before analysis. The work of'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='The work of Near-infrared spectra was to detect absorption bands related to O–H and C–H functional groups in 8 biomass. At that exact time, laboratory chemical analysis was conducted to determine'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='to determine cellulose, hemicellulose, lignin, moisture content, total solids, and volatile solids. These values were taken as references for model calibration and validation. PLSR was employed to'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='was employed to build models that correlated spectral information with laboratory data. To further improve the quality of the spectra, methods such as multiplicative scatter correction and derivative'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and derivative transformation were employed to reduce the effects of light scattering. The performance of the models was evaluated using the coefficient of determination and the root mean square'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='root mean square error of prediction. The work demonstrated that the combination of NIRS with chemometric analysis provides a fast and accurate method for the analysis of lignocellulosic biomass for'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='biomass for bioenergy and bioreactor applications [2]. Feng et al. also explored the application of NIRS for fast biomass analysis in bioreactor-related applications. The biomass samples were dried,'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='samples were dried, ground, and sieved to ensure that the particle size was consistent to reduce the effects of spectral scattering. Diffuse reflectance NIR spectra were measured over a wide'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='over a wide wavelength range to capture the vibration-sensitive absorption bands corresponding to O-H, C-H, and N-H bonds. To improve the quality of data, the various spectral preprocessing'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='preprocessing techniques like derivative transformation, smoothing and standard normal variate correction were used. To prove relation between chemical composition and spectral data, multivariate'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='data, multivariate calibration models were developed using PLSR. For validation and accuracy of the model, statistical measures such as R² and prediction error were used [3]. Christy E. Manyi-Loh and'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='E. Manyi-Loh and Ryk Lues examine the anaerobic digestion of lignocellulosic biomass. The role of lignin, cellulose and hemicellulose in the biodegradation process during the anaerobic digestion is'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='digestion is explain by the authors. For improving the efficiency of hydrolysis and defeating the biomass recalcitrance, various pretreatment methods are used. They also explain effect of pH,'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='effect of pH, temperature and nutrient supplementation on methane and biogas production. Biochemical methane potential analysis was accepted as a standard technique for evaluating digestion'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='digestion efficiency [4]. To evaluate the conversion efficiency of lignocellulosic biomass through controlled processing Md. Wadud Ahmed, Vijay Singh and Mohammed Kamruzzaman perform experiments.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='experiments. Their work assisted in a better comprehension of biomass conversion, performance and its refinement for energy recuperation applications. To examine if the biomass feedstock was'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='feedstock was convenient for transformation in the first place it was checked for cellulose, hemicellulose, lignin, total solids and volatile solids. Prior treatment techniques were utilised to vary'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='utilised to vary the structural intricacy of the biomass and surge its 9 enzymatic and microbiological approachability. Anaerobic digestion studies were conducted in laboratory-scale reactors with'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='reactors with controlled pH and temperature. The digestion process was regularly monitored to assess stability and performance using measurements of biogas volume and methane content [5]. Ning Ai et'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='[5]. Ning Ai et al. quickly assessed the cellulose, hemicellulose, and lignin content of Sargassum horneri using near-infrared spectroscopy. Ning Ai et al. gathered 74 samples of Sargassum horneri,'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Sargassum horneri, cleaned, dried, powdered, and sieved them to create a uniform biomass powder. Ning Ai et al. used the Van Soest method to test the cellulose and hemicellulose contents and standard'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and standard analytical method to measure the lignin concentration. Ning Ai et al. used the diffuse reflectance mode under controlled conditions to get near-infrared spectra in the 12,000–4000 cm⁻¹'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='12,000–4000 cm⁻¹ range. Spectral pretreatment methods such as Savitzky–Golay smoothing, derivatives, standard normal variate, and multiplicative scatter correction were used by Ning Ai et al. Partial'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Ai et al. Partial least squares regression was used by Ning Ai et al. to create calibration models [6]. Xiaoli Li, Chanjun Sun, Binxiong Zhou, and Yong. He studied the contents of hemicellulose,'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of hemicellulose, cellulose, and lignin in moso bamboo using nearinfrared spectroscopy (NIRS). The bamboo samples were taken from various sites and were grind into a fine powder. The chemical'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='The chemical composition of hemicellulose, cellulose, and lignin was studied using the Van Soest method. The near-infrared spectra were scanned within the wavelength range of 1100-2498 nm.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of 1100-2498 nm. Chemometric models were developed using Partial Least Squares Regression (PLSR) with variable selection methods to increase the accuracy of the models [7]. 2.3 Parameters A. PH'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Parameters A. PH Microbial activity and biomass conversion in energy recovery mainly depends on pH. Biomass decomposition such as cellulose and hemicellulose are break down by maintaining a constant'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='a constant pH level. Large changes in pH may affect on how microbes use biomass [3]. B. TOTAL SOLIDS The total quantity of solid matter, whether organic or inorganic, present in biomass is referred'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='biomass is referred to as total solids (TS). The effect of solid concentration on biomass handling and processing capacity is relevant. The total solids concentration needs to be maintained at'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='to be maintained at optimal levels [3]. 10 C. VOLATILE REDUCTION The volatile solids (VS) destruction in the biomass processing reflects the extent of biodegradable organic materials that have been'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='that have been decomposed. The greater the destruction of volatile solids, the better the use of biomass materials such as cellulose and hemicellulose. A method used to determine the effectiveness of'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='effectiveness of biomass decomposition and energy recovery is the volatile solids destruction [3]. D. LIGNIN According to Khaire et al. Lignin is a complex polymer that occurs in plants as well as'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='plants as well as algae. It is the major component that gives strength to plants. Figure 2 shows the chemical structure of lignin. Lignin is necessary for the development of plant cell walls,'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='plant cell walls, especially in bark and wood. This protein support to plants stiffness and stability. Chemically speaking, lignin is a cross-linked phenolic polymer. It possess an amorphous, widely'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='amorphous, widely branched, and changeable aromatic structure but no clear underlying structure. The three fundamental phenylpropane units known as monolignols that comprise lignin are P-coumaryl'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='are P-coumaryl alcohol, coniferyl alcohol, and sinapyl alcohol. Depending on the kind of biomass, different combinations of these monolignols are present. Coniferyl alcohol predominates in softwood'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='in softwood lignin, sinapyl and coniferyl alcohols are present in hardwood lignin, and all three are present in grass lignin. The secondary cell wall contains the majority of lignin. It facilitates'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='It facilitates the passage of nutrients and water via xylem tissues by supporting vascular cells. Lignin is difficult to break down during biomass processing because of its great resistance to'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='great resistance to degradation, which helps shield plants from diseases and microorganisms. The composition of lignin differs among plant species. It usually carry a lot of carbon, hydrogen, oxygen,'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='hydrogen, oxygen, and a small amount of ash. Because of its very asymmetrical and heterogeneous molecular structure, lignin lacks a clearly defined structure in contrast to cellulose and'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='to cellulose and hemicellulose. In industries, lignin is mostly used as fuel. Nevertheless, it can be chemically change and used for many things, like the extraction of heavy metals and the creation'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and the creation of adhesives, surfactants, and activated carbon. Plant biomass carry varying amounts of lignin [10]. The lignin content in woody plants is excessive than that of herbaceous plants,'),
#  Document(metadata={'source': 'lignine.txt'}, page_content="herbaceous plants, which influences the biomass's stiffness and ease of processing. Lignin is tightly associated with structural plant cells, involving wood fibers and sclerenchyma cells, and it"),
#  Document(metadata={'source': 'lignine.txt'}, page_content="cells, and it contributes to the strength and rigidity of plant cell walls. Lignin is generally utilized in procedures that don't require high purity and is produced in vast quantities all around 11"),
#  Document(metadata={'source': 'lignine.txt'}, page_content="all around 11 the world. Plant defensive tissues contain lignin as well as other polymers such cutin, suberin, and waxes. These enhance the plant's resilience and preserve its surface [9]. Lignin is"),
#  Document(metadata={'source': 'lignine.txt'}, page_content='[9]. Lignin is more tough for living organisms to decompose and has a more stable pattern in near-infrared (NIR) light than other plant material components like carbohydrates, according to Fernández'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='to Fernández et al. [1]. According to Zhao et al., it is difficult to predict lignin levels from NIR data since lignin signals can mix with cellulose and hemicellulose signals [2]. Lignin is a'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='[2]. Lignin is a significant structural component of lignocellulosic biomass and is crucial in determining biomass recalcitrance, according to Kristoffer Mega Herdlevaer, Camilla Løhre, Egil Nodland,'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Egil Nodland, and Tanja Barth. Instead of focusing exclusively on tree species, they found that the lignin percentage changes greatly based on biomass fractions such wood, bark, needles, and twigs.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='needles, and twigs. According to the study, wood samples had somewhat lower lignin content than bark samples, which had the greatest lignin content [8]. E. CELLULOSE Khaire et al. found that'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='et al. found that cellulose is one of the main parts of the plant cell wall and plays a big role in making plants strong and rigid. Figure 3, shows chemical structure of Cellulose. Cellulose makes up'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Cellulose makes up about 15 to 30 percent of the dry weight of the primary plant cell wall and is the main part of lignocellulosic biomass. Cellulose is a large molecule made of many glucose units'),
#  Document(metadata={'source': 'lignine.txt'}, page_content="many glucose units linked together in long chains. Compared to hemicellulose, cellulose has a strong, crystal-like structure that doesn't break easily when exposed to water or acid, while"),
#  Document(metadata={'source': 'lignine.txt'}, page_content='or acid, while hemicellulose is not as strong or stable. Cellulose microfibrils are arranged side by side in the cell wall, with sizes usually between 10 and 25 nanometers, and the smaller fibrils'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='the smaller fibrils are about 2 to 4 nanometers wide. When cellulose fibers line up in this way, they form a structure called a micellar structure. Chemically, cellulose is an organic substance with'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='substance with the formula (C₆H₁₀O₅)ₙ and does not dissolve in water or weak acid or alkali solutions at normal room temperatures. Cellulose makes up about 30 to 50 percent of total lignocellulosic'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='lignocellulosic biomass, and the world produces about 120 to 140 billion tons of it every year. The amount and type of cellulose can vary depending on the plant, its species, and how old it is, which'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='old it is, which affects the properties of the biomass and how easily it can be broken down [11]. The primary cell walls of flowering plants and cone-bearing plants are mostly made of cellulose-based'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of cellulose-based sugars. Cotton fibers contain nearly 91 percent cellulose, making it one of the purest natural forms of cellulose compared to cellulose from wood. Cellulose is made up of long'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='is made up of long chains of many β-1,412 linked D-glucose units, forming a straight and regular structure. Each β-Dglucopyranose unit is rotated about 180 degrees compared to the one it was before'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='one it was before it, which makes the molecule more stable and repeatable. These cellulose chains held together using hydrogen bonds and other weak forces between the molecules to form rigid'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='to form rigid microfibrils. Cellulose contains about 6,000 in primary cell walls and can go up to 14,000 in secondary cell walls.  use biomass [3]. Cellulose microfibrils are very crystalline and not'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='crystalline and not water-attracting, which makes the lignocellulosic biomass hard to break down. Cellulose is not only an important part of higher plants but also it is found in algae, bacteria,'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='in algae, bacteria, oomycetes, and other microbes that forms biofilms [9]. Fernández et al. said that cellulose is the main type of polysaccharide in lignocellulosic biomass and has a big effect on'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='has a big effect on how NIR spectra respond because of the O–H groups [1]. Zhao et al. found that cellulose levels can be predicted accurately with NIRS if strong calibration models are created using'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='are created using chemical data as a reference [2].  F. HEMICELLULOSE Khaire et al. said that hemicellulose, which is also called polyose, is a key structural polysaccharide found along with'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='found along with cellulose in the walls of all plant cells. Figure 4, shows chemical structure of Hemicellulose. Hemicellulose is made up of different types of heteropolysaccharides, like'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='like arabinoxylans, xylans, glucomannans, glucuronoxylans, and xyloglucans. These polymers include various sugar units besides glucose, such as arabinose, mannose, xylose, galactose, and rhamnose'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and rhamnose [12]. Hemicellulose has a high amount of D-sugars, mostly pentoses, and in some cases small amounts of L-sugars. Xylose is usually the most common sugar unit in hemicellulose, while'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='while mannose is the main one in softwood hemicellulose. Hemicellulose also contains modified sugar parts like glucuronic acid and galacturonic acid. Because hemicellulose is amorphous, it can be'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='it can be broken down easily by dilute acids, dilute bases, and specific enzymes that target hemicellulose. About 15 to 35 percent of all lignocellulosic biomass is made up of hemicellulose. In terms'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='In terms of structure, hemicellulose is a branched, single-chain, and amorphous heteropolysaccharide. Hemicellulose polymers consist of pentoses, hexoses, uronic acids, and acetylated sugars, with a'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='sugars, with a length of between 500 and 3000 sugar units. The sugar parts in hemicellulose are mostly connected by β-1,4-glycosidic bonds at the O4 spot. Short side chains and lots of branching stop'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of branching stop crystallization, so hemicellulose is not crystalline. The kinds and number of groups on the branches of hemicellulose depend on the type of plant material. Based on the main sugar'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='on the main sugar in the main chain, 13 hemicellulose is divided into arabinans, xylans, mannans, and xyloglucans. Xylan is the most common type of hemicellulose, and its makeup can differ a lot'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='can differ a lot between plant types. Hemicellulose helps make plant cell walls stronger by linking with both cellulose and lignin [9]. Figure 2.2 Chemical structure of Lignin Figure 2.3 Chemical'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Figure 2.3 Chemical structure of Cellulose 14 Figure 2.4 Chemical structure of Hemicellulose G. MOISTURE CONTENT Fernández et al. found that moisture content has a big impact on NIR absorbance'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='on NIR absorbance because of the strong interactions from the O–H bonds. In order to accurately forecast the biomass components, it is crucial to employ strong calibration models, as they found that'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='as they found that the spectra overlap more when there is more moisture [1]. Moisture content, which is the amount of water in the biomass, is a very important factor in biomass processing and'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='processing and storage. High moisture content can have adverse effects on material handling, storage stability, and conversion efficiency in biofuel and bioproduct conversion processes [13]. Water'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='[13]. Water has strong absorption properties in the near-infrared region of the spectrum; hence, moisture content affects near-infrared spectra. It is important to estimate moisture content'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='moisture content accurately for effective biomass analysis and process optimization. Near-infrared spectroscopy is a fast and non-destructive technique for measuring moisture content in different'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='in different types of biomasses [5]. H. FIXED SOLID Fixed solids, also known as ash content, are the inorganic and non-combustible part of biomass that is left after complete combustion. High ash'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='High ash content can be detrimental to the overall performance of biomass because it reduces the amount of biodegradable material and the efficiency of energy conversion. Thus, fixed solids are'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='fixed solids are important factor in biomass analysis. They can be analyzed by high-temperature furnace methods to determine the inorganic residue accurately [2]. 2.4 Research Outcomes 15 Fernández'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='15 Fernández et al. found that Near Infrared Spectroscopy (NIRS) is very efficient for the prediction of moisture content as well as the major components of biomass, including cellulose,'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='cellulose, hemicellulose, and lignin. The results indicated that the changes in moisture content had a significant effect on the regions of the spectrum related to O–H stretching vibrations. With the'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='With the increase in moisture content, the overlapping of the spectra also increased, which in turn affected the accuracy of prediction. However, after applying chemometric calibration techniques,'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='techniques, the accuracy of prediction for cellulose, hemicellulose, and lignin was found to be significantly improved. The authors concluded that accurate control and correction for moisture content'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='moisture content are required for obtaining accurate results when applying NIRS analysis for biomass characterization as per Table 1 [1]. Similarly, Zhao et al. showed that the combination of NIRS'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='combination of NIRS with Partial Least Squares Regression (PLSR) can be used for the accurate prediction of cellulose, hemicellulose, and lignin in agricultural residues. Their results revealed a'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='results revealed a high degree of agreement between predicted values and laboratory reference values for the key structural parts of plant biomass. Spectrum region involving related to C-H and O-H'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='to C-H and O-H bonds were found great importance in enhancing efficiency of models. This paper includes NIRS capacity to handle compositional variations that are present in different crop residues.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='crop residues. The author ensures that NIRS is promising method to assess agricultural biomass in bioenergy conversion plant [2]. Md. Wadud Ahmed, Vijay Singh, and Mohammed Kamruzzaman used strict'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='used strict method for experimental and analytical procedure to evaluate lignocellulosic biomass conversion. Their research focus on feedstock variability including plant characteristic such as'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='such as lignin, cellulose, hemicellulose. This detailed study allows to measure effectiveness of biomass.  It also helps to define most important factor that affect performance of process [5].'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of process [5]. According to Ning Ai et al., the raw near-infrared spectra of Sargassum horneri presented a large overlap of signals, which made it difficult to interpret. The initial models for the'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='models for the prediction of cellulose, hemicellulose, and lignin had only moderate accuracy. But the selection of appropriate spectral variables helped to improve the accuracy of the models. The'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of the models. The interval Partial Least Squares (iPLS) model performed the best, with high accuracy for cellulose and hemicellulose and moderate accuracy for lignin. The predicted values were in'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='values were in close agreement with the laboratory values, which proved the accuracy of the method. The study thus confirmed the effectiveness of NIRS in the rapid and accurate analysis of'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='analysis of lignocellulosic components of marine biomass [14]. 16  17   TABLE 2.1 DIFFERENT FORMS OF LIGNOCELLULOSIC BIOMASS AND THEIR COMPOSITIONAL AND PHYSICOCHEMICAL FEATURES Ref. Biomass Type pH'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Biomass Type pH Total Solids (TS% ) Volatil e Solids (VS, % TS) Ligni n (%) Cellulos e (%) Hemicellulos e (%) Fernández et al., 2019 Olive tree pruning 6.87.5 88–92 75–85 18–25 32–45 20–28 Zhao et'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='32–45 20–28 Zhao et al., 2018 Crop residues 6.57.2 85–93 70–88 12–22 35–48 18–32 Feng et al., 2018 Biofuel pellets 7.07.8 90–95 80–90 15–28 30–46 16–30 ManyiLoh & Lues, 2023 Lignocellulosi c biomass'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='c biomass 6.58.0 80–92 65–85 10–30 30–50 15–35 Ahmed et al., 2025 Agricultural biomass 6.87.6 85–94 75–90 14–26 33–49 18–31 Ning Ai et al., 2022 Sargassum horneri 7.28.1 82–90 68–82 6–12 18–30 20–38'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='6–12 18–30 20–38 Li et al., 2015 Moso bamboo 6.47.0 90–95 78–88 22–30 40–50 20–28 Herdlevæ r et al., 2022 Wood, bark, needles 6.57.3 88–94 70–85 20–35 28–45 15–25 Khaire et al., 2021 Sugarcane tops'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='2021 Sugarcane tops 6.67.4 85–92 75–88 14–21 38–45 25–32 2.5 Summary of Literature Review The above studies show that Near Infrared Spectroscopy (NIRS) is a systematic, fast, and non-destructive'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and non-destructive method for study at basic level of lignocellulosic biomass components, making it very correct for bioreactor analysis. The results show that NIRS can accurately predict values of'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='predict values of all the content such as moisture content, total solids, volatile solids, cellulose, hemicellulose, and lignin. The moisture content showed a major effect on NIR radiation absorption'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='absorption the reason is  O–H bond interactions caused water content problems which resulted in forecasting mistakes.  The studies showed that proper sample handling which includes homogenization and'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='homogenization and particle size reduction must be implemented to achieve better spectral stability and calibration results. The literature demonstrates that NIRS functions as an efficient method for'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='method for quick biomass assessment which helps for continuous measurement of biomass and serves as a faster option than traditional chemical testing methods that require extensive time. The'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='extensive time. The development of very strong calibration models needs to become the main area of research because they must handle biomass type variations and moisture content changes and'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='content changes and structural heterogeneity.  The collaboration of NIRS technology with existing online and offline bioreactor monitoring systems will enable real-time management and process'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and process improvement for anaerobic digestion and biomass transformation. Advanced chemometric and machine learning models can enhance the accuracy of predicting lignocellulosic fractions and key'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='fractions and key process parameters which include volatile solids and total solids. 18 CHAPTER -3 WORK DONE 19 3. WORK DONE 3.1 Overview of Investigation The investigation began with understanding'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='with understanding the project topic. This project is about the analysis of biomass using NIRS technology for bioreactor applications. The main goal was to study how different elements of biomass'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='elements of biomass such as lignin, cellulose and hemicellulose influence the biodegradation process. We did a background study to highlight the importance of biomass as a renewable energy source and'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='energy source and its role in sustainable waste management and waste-to-energy systems. The investigation looked at the limitations of laboratory methods. These methods are time-consuming and costly.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and costly.  To overcome these issues, we focused on Near-Infrared Reflectance Spectroscopy as a technique for non-destructive analysis of lignocellulosic biomass. We explored the working theory of'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='working theory of NIRS technology. Infrared light interacts with biomass samples and the reflected light helps determine chemical composition.  The investigation paid attention to the AS726X spectral'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='the AS726X spectral sensor. This sensor provides real-time data for biomass analysis. It also examined how different wavelengths correspond to components like lignin, cellulose and hemicellulose in'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='hemicellulose in biomass.  We reviewed research papers and previous studies to understand existing methods, findings and advancements in biomass analysis using NIRS technology. The study aimed to'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='The study aimed to find out how differences in lignin content affect the rate of biodegradation of biomass. Generally, a higher lignin content slows the biodegradation process of biomass. The'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of biomass. The feasibility of using NIRS devices in bioreactors for monitoring biomass was also considered. We established a methodology for sample collection, analysis and comparison of'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and comparison of lignocellulosic biomass species. Overall, this phase laid a foundation for the project by defining the problem statement, objectives, tools and expected outcomes of the biomass'),
# ...
#  Document(metadata={'source': 'lignine.txt'}, page_content='light and software for recording and processing spectral data. Researchers first prepare biomass samples for analysis. The preparation involves drying the samples to remove moisture and grinding them'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and grinding them into a powder. This ensures readings. The prepared sample is placed in the sample holder creating a surface. This enhances the connection between the sample and the NIR radiation'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='the NIR radiation reducing errors from scattering. During analysis infrared light is directed onto the biomass sample. The interaction between the radiation and the chemical elements of the biomass'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of the biomass leads to absorption and reflection at wavelengths. This produces a pattern. The detector captures this data, which is transferred to a computer for analysis. Calibration models and'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='models and software tools are used to interpret the spectra and determine the biomass composition. This includes cellulose, hemicellulose and lignin content.  Before starting the experiment, the'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='the experiment, the instrument is calibrated using reference materials. This ensures the results accuracy and reliability. This step helps minimize errors. Researchers control factors such as'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='factors such as temperature, humidity and external light disturbances during the experiment. This maintains consistency. Improves data quality. Overall, the experimental setup allows for a reliable'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='for a reliable study of lignocellulosic biomass using NIRS technology. This makes it an efficient method, for material characterization. Near-Infrared Spectroscopy or NIRS is a way to get information'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='to get information about things. This information is mostly about how infrared radiation interacts with the parts of lignocellulosic biomass.  We collect this information from NIRS. Then we use'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='NIRS. Then we use computer programs to make sense of it. When we look at the information from NIRS it is usually shown as a graph. The x-axis of the graph shows the wavelength in nanometers  and the'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='nanometers  and the y-axis shows how much radiation is absorbed or reflected. Each peak or change in the graph from NIRS corresponds to bonds like the bonds between oxygen and hydrogen, carbon and 24'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='carbon and 24 hydrogen and nitrogen and hydrogen in the biomass. These patterns from NIRS are like a fingerprint of the sample. They help us identify and analyze the chemical structure of the sample'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of the sample from NIRS. Different biomass samples give us patterns from NIRS, based on what they are made of and how they are structured. To make this information from NIRS more useful we use'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='more useful we use techniques, like calibration models. These models help us turn the information from NIRS into values like the percentages of cellulose, hemicellulose and lignin in the sample from'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='in the sample from NIRS.  We often present this information from NIRS in tables so it is easy to compare samples from NIRS. We also use graphs and charts to show how the composition of the samples'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of the samples varies and to identify trends from NIRS. Sometimes we use advanced data analysis methods, like multivariate analysis, to improve the accuracy of the results from NIRS and get'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='from NIRS and get information from the spectral data from NIRS. This helps us reduce noise and make the results from NIRS more reliable. The final result of the NIRS analysis includes both'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='includes both information, which gives us a clear understanding of the biomass structure from NIRS. This information from NIRS is useful for research, quality control and industrial applications.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='applications.  The way we present the information from NIRS is designed to be simple and clear. It is easy to understand and make decisions without having to do tests from NIRS. Overall NIRS gives us'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='NIRS gives us efficient information, which makes it a powerful tool for evaluating and comparing lignocellulosic biomass samples from NIRS. 3.8 Summary of Work Done The work we did in this an'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='we did in this an analysis about using Near-Infrared Spectroscopy or NIRS to study biomass. We did this work to see how NIRS can be used as a way to analyze biomass. We. Did the study in a way so we'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='in a way so we could get reliable results from NIRS. First we learned about biomass and what it is made of including cellulose, hemicellulose and lignin. We also learned about why biomasses important'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='biomasses important for bioenergy and industrial applications. We collected biomass samples from places and labeled them so we could use them for further analysis from NIRS. We made sure the samples'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='sure the samples were representative and not contaminated.  25 We then prepared the samples by drying and grinding them into a form. This was a step because it helped us get consistent and accurate'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and accurate readings when we did the NIRS analysis. We set up the NIR spectrometer. Calibrated it before we started the analysis from NIRS. This ensured that the results from NIRS were accurate and'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='were accurate and repeatable. We then analyzed each sample using NIRS.  We recorded the information from NIRS. The way the infrared radiation interacted with the biomass components gave us spectral'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='gave us spectral signatures for each sample from NIRS. We processed the information from NIRS. Presented it in graphs and tables. We used calibration models to turn the information from NIRS into'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='from NIRS into quantitative results like the composition of the biomass from NIRS. We studied the NIRS results to see how the different samples varied and to evaluate how well the technique from NIRS'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='technique from NIRS worked. Overall, this work shows that NIRS is a non-destructive way to assess lignocellulosic biomass, which makes it suitable for research and industrial applications, from NIRS.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='from NIRS. 26 CHAPTER – 4 RESULT AND DISCUSSION  27 4.RESULT AND DISCUSSION 4.1 Introduction The purpose of this section is to provide an analysis and discussion of the findings produced by the NIRS'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='by the NIRS sensor technology study conducted on lignocellulosic biomass. The main objective of this research is to assess the relationship between the changing composition of biomass (i.e., lignin,'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='(i.e., lignin, cellulose, and hemicellulose) over a period of time and its ability to degrade biologically. NIRS technology allows for a quick, non-destructive analysis of biomass in real time.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='in real time. Unlike the traditional laboratory method of testing, once the measurement has been taken, it is able to continually monitor and decrease the chances of excessive handling of the'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='handling of the samples, which ultimately leads to errors in measurements. The results discussed in this chapter will provide you with the information necessary to determine which types of biomass'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='types of biomass materials are compatible with a bioreactor and how they can perform optimally in a waste to energy system.  4.2 Experimental Setup Overview Biomass samples of Napier grasses were'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Napier grasses were used to conduct the experiment in the study. The experiment examined the structural composition of the stem and leaf portions separately to identify the differences. The natural'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='The natural decomposition of the biomass was measured by collecting the samples at three different time periods of 15, 30, and 60 days. The spectral data from the biomass samples were acquired using'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='were acquired using an AS726X NIRS Sensor. The light emitted from this sensor is in the near-IR range and is directed toward the biomass surface, then the reflected light or energy is analyzed for'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='is analyzed for chemical composition estimation. The relative levels of each chemical component (Lignin, 28 Cellulose and Hemicellulose) can be determined from the spectral data due to their unique'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='due to their unique absorption properties. The experimental set-up was specifically created to not cause any disturbances to the samples while being tested. While obtaining repeated measurements of'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='measurements of the same sample over time, the non-destructive method provided consistent results and ensured the reliability of the observed results.  4.3 Data Acquisition and Transmission The data'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='The data acquiring process included using the NIRS sensor to capture the reflectance values from the biomass samples. The data obtained from the spectral analysis was used to determine the percentage'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='the percentage of cellulose, hemicellulose, and lignin. To observe the variations in composition over time, the experiments were conducted at regular intervals of 15, 30, and 60 days. Collected data'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Collected data was recorded in a very organized manner to allow for ease of comparison of the different stages of degradation and different parts of the plant (stem and leaves).  The system allowed'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='The system allowed continuous and efficient data collection, improving to a much less approach than the observation of data by the human eye. The approach led to an increase in the accuracy and'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='in the accuracy and repeatability of results, which subsequently allowed for detecting even the smallest amount of change in the composition of the biomass. 4.4 Visualization and Dashboard Results'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Dashboard Results The experimental data collected using the NIRS sensor were arranged in tabular forms as well as represented graphically. A graphical method was very effective for analyzing the'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='for analyzing the results derived from experimentation because it enabled the identification of different trends. The graphs that were made based on lignin, cellulose, and hemicellulose'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and hemicellulose concentrations showed the variation among each other.  The values that were taken after 15, 30, and 60 days allowed us to understand the variation of biomass decomposition.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='decomposition. Observations: Lignin content exhibited a rising 29 pattern. Cellulose content depicted a decreasing pattern. Variation pattern observed for hemicellulose. This form of graphical'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='form of graphical representation helped compare the performance of stems and leaves. 4.5 Result Interpretation The results generated through experimental analysis exhibit considerable variability in'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='variability in composition of lignocellulose present in biomass at various stages of growth. These factors affect the biodegradability and performance of biomass in bioreactors. Lignin content'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Lignin content witnessed a steady increase in leaf and stem samples of biomass.  For leaf samples, there was an increase of 49.63% in lignin content between day 15 and 30, and an additional increase'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='additional increase of 48.51% from 30 to 60 days. In stem samples, there was an increase of 29.49% in lignin content during the first stage of experiment (15–30 days), and further increase by 59.41%'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='increase by 59.41% during the second stage of experiment (30–60 days). Thus, steady increase in lignin content implies that the biomass gets gradually more resistant to biodegradability due to higher'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='due to higher structural complexity. On the contrary, content of cellulose in leaf samples was found to decline. There was a decline of 4.67% in cellulose content between day 15 and 30 and a sharp'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and 30 and a sharp decline of 30.34% from day 30 to 60. The result clearly suggests that cellulose undergoes active breakdown and consumption for energy by microbes. Content of hemicellulose was'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='hemicellulose was found to vary considerably in the two sample sets.In leaves, it decreased by 16.67% between Day 15 and Day 30, but later increased by 47.57% from Day 30 to Day 60. Similarly, in'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='60. Similarly, in stem samples, hemicellulose decreased by 27.33% in the initial phase and then increased by 25.23% in the later phase. This variation can be explained by the partial degradation of'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='degradation of hemicellulose in the early stage and its relative increase in proportion as cellulose content decreases. Overall, the results highlight that lignin acts as a limiting factor in'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='limiting factor in biodegradation, while cellulose contributes positively to microbial activity. The variation of hemicellulose values indicates its transitional role in the degradation process')]

# %%
# Text slitter
from langchain_text_splitters import RecursiveCharacterTextSplitter
textSplitter = RecursiveCharacterTextSplitter(chunk_size=200, chunk_overlap=20)
finalDocuments = textSplitter.split_documents(text_documents)
finalDocuments
# Out:
# [Document(metadata={'source': 'lignine.txt'}, page_content='1.INTRODUCTION 1.1 Background  Lignocellulosic biomass is not the keyword that is being used in the sustainability circles, Lignocellulosic biomass is the foundation of the green energy revolution'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='energy revolution that is to come. Consider: starchy agricultural waste, such as rice husks and wheat straw and sugarcane bagasse; wood waste such as logging or construction sites; or specific energy'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='or specific energy crops, such as switchgrass or maiden grass. These sources are rich, they are renewable and most importantly, they are carbon-neutral in the right hands. Biomass is a recycled'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='is a recycled carbon previously taken into the atmosphere by plants unlike fossil fuels which release the old carbon that was in the atmosphere through pumping. In India alone, where more than 40'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='where more than 40 percent of the labour force is engaged in agriculture, we produce some 500 million tons of crop residues every year, most of it burned in the open air, and adding to air pollution'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='to air pollution and lost opportunities. The bioenergy initiative has gone on a rampage over the past few decades. The world is rapidly increasing energy demand, it has been projected that by the'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='that by the year 2050, the world will need to cut down by half, and the climate change is holding us to the task of reducing emissions. Introduce biofuels: ethanol, biodiesel, biogas, each of them'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='each of them based on the biomass feedstock. The hike here lies however, when lignocellulose is not that simple to pick. It is a hard nut whose three divorced polymers are cellulose (40-50, the'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='(40-50, the sugarrich backbone), hemicellulose (20-35, the branched supporter) and lignin (15-30, the rigid glue that cannot be broken down). This is a structure that has developed in plants to avoid'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='in plants to avoid microbes and insects hence this is a strong hold against industrial processing. This is the point at which high-tech locksmiths like advanced sensing come in. The NIRS has become a'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='NIRS has become a game changer. NIRS works within 780-2500 nm range of wavelength and illuminate’s samples using near-infrared light and records the light that is reflected or transmitted. The waste'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='The waste is transformed into an engineered fuel source which opens the door to sustainable bioenergy that will be able to fuel homes and automobiles as well as industries without the carbon'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='without the carbon hangover. Operating on scales which have small difference of cellulose crystallinity or lignin content can create or destroy products, bioreactors are the bubbling vats on which'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='vats on which microbes are fed biomass and produce fuels.  2 1.2 Motivation for the Study  The main aim of this research is to improve the utilization of renewable resources such as plant biomass'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='as plant biomass while reducing negative environmental impacts. At this time, many industries depend heavily on fossil fuels, which contribute to greenhouse gas emissions and environmental pollution.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='pollution. At the same time, large amounts of lignin produced from agricultural and industrial activities are either discarded or burned rather.  While it can be converted into useful products or'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='useful products or energy. Developing a rapid and better efficient method for analyzing plant materials could help industries identify better ways to reuse biomass and select suitable materials and'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='materials and pretreatment methods. A simple and effective monitoring system would also benefit  small to small rural industries as well as large industrial facilities by enabling them to process'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='them to process biomass in a more economical and efficient manner. 1.3 Significance of the Study  This study is important for several reasons. From an environmental perspective, it promotes'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='it promotes sustainable development and reduces waste generation. It also promotes the development of new biomaterial products such as adhesives, composites and biodegradable materials. From an'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='materials. From an academic perspective, the study contributes to knowledge related to the use of sensor technologies for biomass analysis and degradation monitoring. This knowledge can support the'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='can support the development of smart bioreactors and other advanced waste-to-resource systems. When implemented effectively, such monitoring systems can reduce reliance on nonrenewable resources and'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='resources and help address the growing problem of agricultural waste management. 3 1.4 Problem Statement  Although bioreactor designs have improved over time, challenges still remain in the efficient'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='in the efficient degradation of plant materials. Plant biomass varies widely in composition and structural characteristics. Currently, most systems lack real-time monitoring, making it difficult to'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='it difficult to maintain optimal environmental conditions for microorganisms responsible for biomass degradation. As a result, the efficiency of biomass degradation, gas production and overall'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and overall processing time can be negatively affected. Therefore, there is a need for a system capable of measuring biomass characteristics and monitoring the degradation process in real time while'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='in real time while providing feedback for improved process control. 1.5 Aim and Objectives  The purpose of this study is to develop a sensor-based system to measure the properties of plant residues'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of plant residues and monitor their degradation. The main objectives are as follow: • To develop method that helps to determine plant characteristics of their residue that influence the degradation.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='the degradation. • To develop sensor that should be multi-capable of monitoring components like  Cellulose, lignin, hemicellulose. • To integrate monitoring system with Internet of Things technology.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Things technology. • For deeper understanding of impact of onsite monitoring data on basis on bioreactor application. 1.6 Scope of the Study  The scope of this study focuses on sensor-based'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='on sensor-based monitoring of biomass degradation inside a bioreactor. The research involves analyzing plant samples, placing sensors 4 within the reactor, and linking sensor data to reactor'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='data to reactor performance. The experiments are conducted at laboratory and pilot scales rather than full industrial scale. The main objective is to develop and demonstrate a process and methodology'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and methodology that could later be scaled up for industrial applications. 1.7 Research Questions  The real time problem faced are guide by this research: 1. How can the degradation of plant biomass'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of plant biomass be effectively measured? 2. How does the composition of plant biomass influence degradation? 3. Can real-time measurements be used to improve control of bioreactors? 4. How can this'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='4. How can this system support future? 1.8 Major Contributions   The main contributions of this work include:  • Design and demonstration of sensor network that helps in monitoring degradation of'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='degradation of plant biomasses. • Development of an IoT- based data logging system. • Experimental demonstration that shows improved degradation through monitoring. • Establishment of correlations'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of correlations among the biomass chemicals composition and degradation.  1.9 Organization of the Thesis  The remaining chapters are organized as follows. Chapter 2 reviews previous work related to'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='work related to biomass characterization and sensor-based bioreactor monitoring.  Chapter 3 explains the system design, the working principles, and the experimental approach.  Chapter 4 presents the'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='4 presents the results and discusses system performance.  Chapter 5 summarizes the findings, offers conclusions, and suggests avenues for future research.  Chapter 6 provides supporting material and'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='material and appendices.  5 CHAPTER – 2 REVIEW OF LITERATURE 6 2. REVIEW OF LITERATURE 2.1 Overview Agricultural waste is becoming more efficient as the demand for biofuels as well as bioproduct is'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='as bioproduct is continuously increasing. However, there are significant obstacles because they come from a wide variety of sources and takes a long time to decompose, making it more difficult to use'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='difficult to use as a resource. Biomass straws, primarily from crops including rice, corn, wheat, and rapeseed, were employed as study materials.  "Lignocellulosic material," a naturally occurring'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='naturally occurring mixture of cellulose, hemicellulose, and lignin, makes up the majority of plant material. These components give plants their strength and structure, and they also influence how'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='also influence how quickly living organisms may break down the material. Due of its speed, near infrared spectroscopy (NIR) is employed in numerous fields. No additional ingredients, chemicals, or'),
#  Document(metadata={'source': 'lignine.txt'}, page_content="chemicals, or specific preparation are required. It doesn't produce any garbage either.  First-generation biomass is derived from food crops; second-generation biomass is derived from lignocellulosic"),
#  Document(metadata={'source': 'lignine.txt'}, page_content='lignocellulosic materials; and third- and fourth-generation biomass is derived from microalgae. One ample and renewable resource derived from plants is lignocellulosic biomass. Growing and processing'),
#  Document(metadata={'source': 'lignine.txt'}, page_content="and processing agricultural products such as fruits, vegetables, meat, fowl, milk products, and crops results in agricultural wastes. Figure 1, depicts India's annual production of agricultural"),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of agricultural waste.  Depending on the kind of agricultural product, these wastes can be solid, liquid, or a thick mixture. Fossil fuels are becoming more and more necessary as development'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='as development advances. However, excessive usage of these finite fuels has led to an energy crisis. Climate change, contaminated air, and other environmental concerns are also brought about by it.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='about by it. There are two types of procedures for analysing lignocellulose: chemical methods and instrumental methods. Chemical procedures are less accurate than instrumental techniques like gas'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='techniques like gas chromatography (GC) and excellent-performance liquid chromatography (HPLC). 7 Figure 2.1 Yearly agriculture waste production in India (Report on State of Indian Agriculture'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Indian Agriculture 2015–16). 2.2 Methodology Fernández et al. checked the chemical composition of lignocellulosic biomass using Near Infrared Spectroscopy (NIRS), a rapid and non-destructive'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and non-destructive technique. Before conducting the spectrum measurements, they gathered the biomass samples, let them to dry, then crushed them until the particles were all the same size. The NIR'),
#  Document(metadata={'source': 'lignine.txt'}, page_content="same size. The NIR spectra were collected within a specific range of wavelengths to identify the absorption patterns associated with the biomass's O–H, C–H, and N–H groups. To increase the efficiency"),
#  Document(metadata={'source': 'lignine.txt'}, page_content='the efficiency of NIRS models they carried chemical tests on lignin, cellulose, hemicellulose, moisture. Partial Least Squares Regression (PLSR) method was used to find correlations between spectral'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='between spectral information and chemical values. To enhance the reliability of predictions, scatter correction and normalization methods were employed as preprocessing tools to eliminate error in'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='eliminate error in spectral information. The performance of the models was determined by using statistical measures which includes the coefficient of determination (R²) and prediction error values.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='error values. The results showed that Near Infrared Spectroscopy (NIRS) is an efficient method for predicting various components and moisture content in lignocellulosic materials. Thus, making this'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Thus, making this method efficient for bioreactor and bioreactor applications [1]. Zhao et al. created model based on NIRS to measure lignocellulosic components in crop residues. The samples that'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='The samples that used by Zhao et al. were obtained from different agricultural sources. The obtained sources were dried and ground it to uniform size particles before analysis. The work of'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='The work of Near-infrared spectra was to detect absorption bands related to O–H and C–H functional groups in 8 biomass. At that exact time, laboratory chemical analysis was conducted to determine'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='to determine cellulose, hemicellulose, lignin, moisture content, total solids, and volatile solids. These values were taken as references for model calibration and validation. PLSR was employed to'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='was employed to build models that correlated spectral information with laboratory data. To further improve the quality of the spectra, methods such as multiplicative scatter correction and derivative'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and derivative transformation were employed to reduce the effects of light scattering. The performance of the models was evaluated using the coefficient of determination and the root mean square'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='root mean square error of prediction. The work demonstrated that the combination of NIRS with chemometric analysis provides a fast and accurate method for the analysis of lignocellulosic biomass for'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='biomass for bioenergy and bioreactor applications [2]. Feng et al. also explored the application of NIRS for fast biomass analysis in bioreactor-related applications. The biomass samples were dried,'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='samples were dried, ground, and sieved to ensure that the particle size was consistent to reduce the effects of spectral scattering. Diffuse reflectance NIR spectra were measured over a wide'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='over a wide wavelength range to capture the vibration-sensitive absorption bands corresponding to O-H, C-H, and N-H bonds. To improve the quality of data, the various spectral preprocessing'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='preprocessing techniques like derivative transformation, smoothing and standard normal variate correction were used. To prove relation between chemical composition and spectral data, multivariate'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='data, multivariate calibration models were developed using PLSR. For validation and accuracy of the model, statistical measures such as R² and prediction error were used [3]. Christy E. Manyi-Loh and'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='E. Manyi-Loh and Ryk Lues examine the anaerobic digestion of lignocellulosic biomass. The role of lignin, cellulose and hemicellulose in the biodegradation process during the anaerobic digestion is'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='digestion is explain by the authors. For improving the efficiency of hydrolysis and defeating the biomass recalcitrance, various pretreatment methods are used. They also explain effect of pH,'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='effect of pH, temperature and nutrient supplementation on methane and biogas production. Biochemical methane potential analysis was accepted as a standard technique for evaluating digestion'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='digestion efficiency [4]. To evaluate the conversion efficiency of lignocellulosic biomass through controlled processing Md. Wadud Ahmed, Vijay Singh and Mohammed Kamruzzaman perform experiments.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='experiments. Their work assisted in a better comprehension of biomass conversion, performance and its refinement for energy recuperation applications. To examine if the biomass feedstock was'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='feedstock was convenient for transformation in the first place it was checked for cellulose, hemicellulose, lignin, total solids and volatile solids. Prior treatment techniques were utilised to vary'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='utilised to vary the structural intricacy of the biomass and surge its 9 enzymatic and microbiological approachability. Anaerobic digestion studies were conducted in laboratory-scale reactors with'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='reactors with controlled pH and temperature. The digestion process was regularly monitored to assess stability and performance using measurements of biogas volume and methane content [5]. Ning Ai et'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='[5]. Ning Ai et al. quickly assessed the cellulose, hemicellulose, and lignin content of Sargassum horneri using near-infrared spectroscopy. Ning Ai et al. gathered 74 samples of Sargassum horneri,'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Sargassum horneri, cleaned, dried, powdered, and sieved them to create a uniform biomass powder. Ning Ai et al. used the Van Soest method to test the cellulose and hemicellulose contents and standard'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and standard analytical method to measure the lignin concentration. Ning Ai et al. used the diffuse reflectance mode under controlled conditions to get near-infrared spectra in the 12,000–4000 cm⁻¹'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='12,000–4000 cm⁻¹ range. Spectral pretreatment methods such as Savitzky–Golay smoothing, derivatives, standard normal variate, and multiplicative scatter correction were used by Ning Ai et al. Partial'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Ai et al. Partial least squares regression was used by Ning Ai et al. to create calibration models [6]. Xiaoli Li, Chanjun Sun, Binxiong Zhou, and Yong. He studied the contents of hemicellulose,'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of hemicellulose, cellulose, and lignin in moso bamboo using nearinfrared spectroscopy (NIRS). The bamboo samples were taken from various sites and were grind into a fine powder. The chemical'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='The chemical composition of hemicellulose, cellulose, and lignin was studied using the Van Soest method. The near-infrared spectra were scanned within the wavelength range of 1100-2498 nm.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of 1100-2498 nm. Chemometric models were developed using Partial Least Squares Regression (PLSR) with variable selection methods to increase the accuracy of the models [7]. 2.3 Parameters A. PH'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Parameters A. PH Microbial activity and biomass conversion in energy recovery mainly depends on pH. Biomass decomposition such as cellulose and hemicellulose are break down by maintaining a constant'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='a constant pH level. Large changes in pH may affect on how microbes use biomass [3]. B. TOTAL SOLIDS The total quantity of solid matter, whether organic or inorganic, present in biomass is referred'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='biomass is referred to as total solids (TS). The effect of solid concentration on biomass handling and processing capacity is relevant. The total solids concentration needs to be maintained at'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='to be maintained at optimal levels [3]. 10 C. VOLATILE REDUCTION The volatile solids (VS) destruction in the biomass processing reflects the extent of biodegradable organic materials that have been'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='that have been decomposed. The greater the destruction of volatile solids, the better the use of biomass materials such as cellulose and hemicellulose. A method used to determine the effectiveness of'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='effectiveness of biomass decomposition and energy recovery is the volatile solids destruction [3]. D. LIGNIN According to Khaire et al. Lignin is a complex polymer that occurs in plants as well as'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='plants as well as algae. It is the major component that gives strength to plants. Figure 2 shows the chemical structure of lignin. Lignin is necessary for the development of plant cell walls,'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='plant cell walls, especially in bark and wood. This protein support to plants stiffness and stability. Chemically speaking, lignin is a cross-linked phenolic polymer. It possess an amorphous, widely'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='amorphous, widely branched, and changeable aromatic structure but no clear underlying structure. The three fundamental phenylpropane units known as monolignols that comprise lignin are P-coumaryl'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='are P-coumaryl alcohol, coniferyl alcohol, and sinapyl alcohol. Depending on the kind of biomass, different combinations of these monolignols are present. Coniferyl alcohol predominates in softwood'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='in softwood lignin, sinapyl and coniferyl alcohols are present in hardwood lignin, and all three are present in grass lignin. The secondary cell wall contains the majority of lignin. It facilitates'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='It facilitates the passage of nutrients and water via xylem tissues by supporting vascular cells. Lignin is difficult to break down during biomass processing because of its great resistance to'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='great resistance to degradation, which helps shield plants from diseases and microorganisms. The composition of lignin differs among plant species. It usually carry a lot of carbon, hydrogen, oxygen,'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='hydrogen, oxygen, and a small amount of ash. Because of its very asymmetrical and heterogeneous molecular structure, lignin lacks a clearly defined structure in contrast to cellulose and'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='to cellulose and hemicellulose. In industries, lignin is mostly used as fuel. Nevertheless, it can be chemically change and used for many things, like the extraction of heavy metals and the creation'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and the creation of adhesives, surfactants, and activated carbon. Plant biomass carry varying amounts of lignin [10]. The lignin content in woody plants is excessive than that of herbaceous plants,'),
#  Document(metadata={'source': 'lignine.txt'}, page_content="herbaceous plants, which influences the biomass's stiffness and ease of processing. Lignin is tightly associated with structural plant cells, involving wood fibers and sclerenchyma cells, and it"),
#  Document(metadata={'source': 'lignine.txt'}, page_content="cells, and it contributes to the strength and rigidity of plant cell walls. Lignin is generally utilized in procedures that don't require high purity and is produced in vast quantities all around 11"),
#  Document(metadata={'source': 'lignine.txt'}, page_content="all around 11 the world. Plant defensive tissues contain lignin as well as other polymers such cutin, suberin, and waxes. These enhance the plant's resilience and preserve its surface [9]. Lignin is"),
#  Document(metadata={'source': 'lignine.txt'}, page_content='[9]. Lignin is more tough for living organisms to decompose and has a more stable pattern in near-infrared (NIR) light than other plant material components like carbohydrates, according to Fernández'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='to Fernández et al. [1]. According to Zhao et al., it is difficult to predict lignin levels from NIR data since lignin signals can mix with cellulose and hemicellulose signals [2]. Lignin is a'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='[2]. Lignin is a significant structural component of lignocellulosic biomass and is crucial in determining biomass recalcitrance, according to Kristoffer Mega Herdlevaer, Camilla Løhre, Egil Nodland,'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Egil Nodland, and Tanja Barth. Instead of focusing exclusively on tree species, they found that the lignin percentage changes greatly based on biomass fractions such wood, bark, needles, and twigs.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='needles, and twigs. According to the study, wood samples had somewhat lower lignin content than bark samples, which had the greatest lignin content [8]. E. CELLULOSE Khaire et al. found that'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='et al. found that cellulose is one of the main parts of the plant cell wall and plays a big role in making plants strong and rigid. Figure 3, shows chemical structure of Cellulose. Cellulose makes up'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Cellulose makes up about 15 to 30 percent of the dry weight of the primary plant cell wall and is the main part of lignocellulosic biomass. Cellulose is a large molecule made of many glucose units'),
#  Document(metadata={'source': 'lignine.txt'}, page_content="many glucose units linked together in long chains. Compared to hemicellulose, cellulose has a strong, crystal-like structure that doesn't break easily when exposed to water or acid, while"),
#  Document(metadata={'source': 'lignine.txt'}, page_content='or acid, while hemicellulose is not as strong or stable. Cellulose microfibrils are arranged side by side in the cell wall, with sizes usually between 10 and 25 nanometers, and the smaller fibrils'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='the smaller fibrils are about 2 to 4 nanometers wide. When cellulose fibers line up in this way, they form a structure called a micellar structure. Chemically, cellulose is an organic substance with'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='substance with the formula (C₆H₁₀O₅)ₙ and does not dissolve in water or weak acid or alkali solutions at normal room temperatures. Cellulose makes up about 30 to 50 percent of total lignocellulosic'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='lignocellulosic biomass, and the world produces about 120 to 140 billion tons of it every year. The amount and type of cellulose can vary depending on the plant, its species, and how old it is, which'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='old it is, which affects the properties of the biomass and how easily it can be broken down [11]. The primary cell walls of flowering plants and cone-bearing plants are mostly made of cellulose-based'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of cellulose-based sugars. Cotton fibers contain nearly 91 percent cellulose, making it one of the purest natural forms of cellulose compared to cellulose from wood. Cellulose is made up of long'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='is made up of long chains of many β-1,412 linked D-glucose units, forming a straight and regular structure. Each β-Dglucopyranose unit is rotated about 180 degrees compared to the one it was before'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='one it was before it, which makes the molecule more stable and repeatable. These cellulose chains held together using hydrogen bonds and other weak forces between the molecules to form rigid'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='to form rigid microfibrils. Cellulose contains about 6,000 in primary cell walls and can go up to 14,000 in secondary cell walls.  use biomass [3]. Cellulose microfibrils are very crystalline and not'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='crystalline and not water-attracting, which makes the lignocellulosic biomass hard to break down. Cellulose is not only an important part of higher plants but also it is found in algae, bacteria,'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='in algae, bacteria, oomycetes, and other microbes that forms biofilms [9]. Fernández et al. said that cellulose is the main type of polysaccharide in lignocellulosic biomass and has a big effect on'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='has a big effect on how NIR spectra respond because of the O–H groups [1]. Zhao et al. found that cellulose levels can be predicted accurately with NIRS if strong calibration models are created using'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='are created using chemical data as a reference [2].  F. HEMICELLULOSE Khaire et al. said that hemicellulose, which is also called polyose, is a key structural polysaccharide found along with'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='found along with cellulose in the walls of all plant cells. Figure 4, shows chemical structure of Hemicellulose. Hemicellulose is made up of different types of heteropolysaccharides, like'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='like arabinoxylans, xylans, glucomannans, glucuronoxylans, and xyloglucans. These polymers include various sugar units besides glucose, such as arabinose, mannose, xylose, galactose, and rhamnose'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and rhamnose [12]. Hemicellulose has a high amount of D-sugars, mostly pentoses, and in some cases small amounts of L-sugars. Xylose is usually the most common sugar unit in hemicellulose, while'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='while mannose is the main one in softwood hemicellulose. Hemicellulose also contains modified sugar parts like glucuronic acid and galacturonic acid. Because hemicellulose is amorphous, it can be'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='it can be broken down easily by dilute acids, dilute bases, and specific enzymes that target hemicellulose. About 15 to 35 percent of all lignocellulosic biomass is made up of hemicellulose. In terms'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='In terms of structure, hemicellulose is a branched, single-chain, and amorphous heteropolysaccharide. Hemicellulose polymers consist of pentoses, hexoses, uronic acids, and acetylated sugars, with a'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='sugars, with a length of between 500 and 3000 sugar units. The sugar parts in hemicellulose are mostly connected by β-1,4-glycosidic bonds at the O4 spot. Short side chains and lots of branching stop'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of branching stop crystallization, so hemicellulose is not crystalline. The kinds and number of groups on the branches of hemicellulose depend on the type of plant material. Based on the main sugar'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='on the main sugar in the main chain, 13 hemicellulose is divided into arabinans, xylans, mannans, and xyloglucans. Xylan is the most common type of hemicellulose, and its makeup can differ a lot'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='can differ a lot between plant types. Hemicellulose helps make plant cell walls stronger by linking with both cellulose and lignin [9]. Figure 2.2 Chemical structure of Lignin Figure 2.3 Chemical'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Figure 2.3 Chemical structure of Cellulose 14 Figure 2.4 Chemical structure of Hemicellulose G. MOISTURE CONTENT Fernández et al. found that moisture content has a big impact on NIR absorbance'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='on NIR absorbance because of the strong interactions from the O–H bonds. In order to accurately forecast the biomass components, it is crucial to employ strong calibration models, as they found that'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='as they found that the spectra overlap more when there is more moisture [1]. Moisture content, which is the amount of water in the biomass, is a very important factor in biomass processing and'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='processing and storage. High moisture content can have adverse effects on material handling, storage stability, and conversion efficiency in biofuel and bioproduct conversion processes [13]. Water'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='[13]. Water has strong absorption properties in the near-infrared region of the spectrum; hence, moisture content affects near-infrared spectra. It is important to estimate moisture content'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='moisture content accurately for effective biomass analysis and process optimization. Near-infrared spectroscopy is a fast and non-destructive technique for measuring moisture content in different'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='in different types of biomasses [5]. H. FIXED SOLID Fixed solids, also known as ash content, are the inorganic and non-combustible part of biomass that is left after complete combustion. High ash'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='High ash content can be detrimental to the overall performance of biomass because it reduces the amount of biodegradable material and the efficiency of energy conversion. Thus, fixed solids are'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='fixed solids are important factor in biomass analysis. They can be analyzed by high-temperature furnace methods to determine the inorganic residue accurately [2]. 2.4 Research Outcomes 15 Fernández'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='15 Fernández et al. found that Near Infrared Spectroscopy (NIRS) is very efficient for the prediction of moisture content as well as the major components of biomass, including cellulose,'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='cellulose, hemicellulose, and lignin. The results indicated that the changes in moisture content had a significant effect on the regions of the spectrum related to O–H stretching vibrations. With the'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='With the increase in moisture content, the overlapping of the spectra also increased, which in turn affected the accuracy of prediction. However, after applying chemometric calibration techniques,'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='techniques, the accuracy of prediction for cellulose, hemicellulose, and lignin was found to be significantly improved. The authors concluded that accurate control and correction for moisture content'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='moisture content are required for obtaining accurate results when applying NIRS analysis for biomass characterization as per Table 1 [1]. Similarly, Zhao et al. showed that the combination of NIRS'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='combination of NIRS with Partial Least Squares Regression (PLSR) can be used for the accurate prediction of cellulose, hemicellulose, and lignin in agricultural residues. Their results revealed a'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='results revealed a high degree of agreement between predicted values and laboratory reference values for the key structural parts of plant biomass. Spectrum region involving related to C-H and O-H'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='to C-H and O-H bonds were found great importance in enhancing efficiency of models. This paper includes NIRS capacity to handle compositional variations that are present in different crop residues.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='crop residues. The author ensures that NIRS is promising method to assess agricultural biomass in bioenergy conversion plant [2]. Md. Wadud Ahmed, Vijay Singh, and Mohammed Kamruzzaman used strict'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='used strict method for experimental and analytical procedure to evaluate lignocellulosic biomass conversion. Their research focus on feedstock variability including plant characteristic such as'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='such as lignin, cellulose, hemicellulose. This detailed study allows to measure effectiveness of biomass.  It also helps to define most important factor that affect performance of process [5].'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of process [5]. According to Ning Ai et al., the raw near-infrared spectra of Sargassum horneri presented a large overlap of signals, which made it difficult to interpret. The initial models for the'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='models for the prediction of cellulose, hemicellulose, and lignin had only moderate accuracy. But the selection of appropriate spectral variables helped to improve the accuracy of the models. The'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of the models. The interval Partial Least Squares (iPLS) model performed the best, with high accuracy for cellulose and hemicellulose and moderate accuracy for lignin. The predicted values were in'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='values were in close agreement with the laboratory values, which proved the accuracy of the method. The study thus confirmed the effectiveness of NIRS in the rapid and accurate analysis of'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='analysis of lignocellulosic components of marine biomass [14]. 16  17   TABLE 2.1 DIFFERENT FORMS OF LIGNOCELLULOSIC BIOMASS AND THEIR COMPOSITIONAL AND PHYSICOCHEMICAL FEATURES Ref. Biomass Type pH'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Biomass Type pH Total Solids (TS% ) Volatil e Solids (VS, % TS) Ligni n (%) Cellulos e (%) Hemicellulos e (%) Fernández et al., 2019 Olive tree pruning 6.87.5 88–92 75–85 18–25 32–45 20–28 Zhao et'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='32–45 20–28 Zhao et al., 2018 Crop residues 6.57.2 85–93 70–88 12–22 35–48 18–32 Feng et al., 2018 Biofuel pellets 7.07.8 90–95 80–90 15–28 30–46 16–30 ManyiLoh & Lues, 2023 Lignocellulosi c biomass'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='c biomass 6.58.0 80–92 65–85 10–30 30–50 15–35 Ahmed et al., 2025 Agricultural biomass 6.87.6 85–94 75–90 14–26 33–49 18–31 Ning Ai et al., 2022 Sargassum horneri 7.28.1 82–90 68–82 6–12 18–30 20–38'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='6–12 18–30 20–38 Li et al., 2015 Moso bamboo 6.47.0 90–95 78–88 22–30 40–50 20–28 Herdlevæ r et al., 2022 Wood, bark, needles 6.57.3 88–94 70–85 20–35 28–45 15–25 Khaire et al., 2021 Sugarcane tops'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='2021 Sugarcane tops 6.67.4 85–92 75–88 14–21 38–45 25–32 2.5 Summary of Literature Review The above studies show that Near Infrared Spectroscopy (NIRS) is a systematic, fast, and non-destructive'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and non-destructive method for study at basic level of lignocellulosic biomass components, making it very correct for bioreactor analysis. The results show that NIRS can accurately predict values of'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='predict values of all the content such as moisture content, total solids, volatile solids, cellulose, hemicellulose, and lignin. The moisture content showed a major effect on NIR radiation absorption'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='absorption the reason is  O–H bond interactions caused water content problems which resulted in forecasting mistakes.  The studies showed that proper sample handling which includes homogenization and'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='homogenization and particle size reduction must be implemented to achieve better spectral stability and calibration results. The literature demonstrates that NIRS functions as an efficient method for'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='method for quick biomass assessment which helps for continuous measurement of biomass and serves as a faster option than traditional chemical testing methods that require extensive time. The'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='extensive time. The development of very strong calibration models needs to become the main area of research because they must handle biomass type variations and moisture content changes and'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='content changes and structural heterogeneity.  The collaboration of NIRS technology with existing online and offline bioreactor monitoring systems will enable real-time management and process'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and process improvement for anaerobic digestion and biomass transformation. Advanced chemometric and machine learning models can enhance the accuracy of predicting lignocellulosic fractions and key'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='fractions and key process parameters which include volatile solids and total solids. 18 CHAPTER -3 WORK DONE 19 3. WORK DONE 3.1 Overview of Investigation The investigation began with understanding'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='with understanding the project topic. This project is about the analysis of biomass using NIRS technology for bioreactor applications. The main goal was to study how different elements of biomass'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='elements of biomass such as lignin, cellulose and hemicellulose influence the biodegradation process. We did a background study to highlight the importance of biomass as a renewable energy source and'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='energy source and its role in sustainable waste management and waste-to-energy systems. The investigation looked at the limitations of laboratory methods. These methods are time-consuming and costly.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and costly.  To overcome these issues, we focused on Near-Infrared Reflectance Spectroscopy as a technique for non-destructive analysis of lignocellulosic biomass. We explored the working theory of'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='working theory of NIRS technology. Infrared light interacts with biomass samples and the reflected light helps determine chemical composition.  The investigation paid attention to the AS726X spectral'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='the AS726X spectral sensor. This sensor provides real-time data for biomass analysis. It also examined how different wavelengths correspond to components like lignin, cellulose and hemicellulose in'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='hemicellulose in biomass.  We reviewed research papers and previous studies to understand existing methods, findings and advancements in biomass analysis using NIRS technology. The study aimed to'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='The study aimed to find out how differences in lignin content affect the rate of biodegradation of biomass. Generally, a higher lignin content slows the biodegradation process of biomass. The'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of biomass. The feasibility of using NIRS devices in bioreactors for monitoring biomass was also considered. We established a methodology for sample collection, analysis and comparison of'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and comparison of lignocellulosic biomass species. Overall, this phase laid a foundation for the project by defining the problem statement, objectives, tools and expected outcomes of the biomass'),
# ...
#  Document(metadata={'source': 'lignine.txt'}, page_content='light and software for recording and processing spectral data. Researchers first prepare biomass samples for analysis. The preparation involves drying the samples to remove moisture and grinding them'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and grinding them into a powder. This ensures readings. The prepared sample is placed in the sample holder creating a surface. This enhances the connection between the sample and the NIR radiation'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='the NIR radiation reducing errors from scattering. During analysis infrared light is directed onto the biomass sample. The interaction between the radiation and the chemical elements of the biomass'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of the biomass leads to absorption and reflection at wavelengths. This produces a pattern. The detector captures this data, which is transferred to a computer for analysis. Calibration models and'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='models and software tools are used to interpret the spectra and determine the biomass composition. This includes cellulose, hemicellulose and lignin content.  Before starting the experiment, the'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='the experiment, the instrument is calibrated using reference materials. This ensures the results accuracy and reliability. This step helps minimize errors. Researchers control factors such as'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='factors such as temperature, humidity and external light disturbances during the experiment. This maintains consistency. Improves data quality. Overall, the experimental setup allows for a reliable'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='for a reliable study of lignocellulosic biomass using NIRS technology. This makes it an efficient method, for material characterization. Near-Infrared Spectroscopy or NIRS is a way to get information'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='to get information about things. This information is mostly about how infrared radiation interacts with the parts of lignocellulosic biomass.  We collect this information from NIRS. Then we use'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='NIRS. Then we use computer programs to make sense of it. When we look at the information from NIRS it is usually shown as a graph. The x-axis of the graph shows the wavelength in nanometers  and the'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='nanometers  and the y-axis shows how much radiation is absorbed or reflected. Each peak or change in the graph from NIRS corresponds to bonds like the bonds between oxygen and hydrogen, carbon and 24'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='carbon and 24 hydrogen and nitrogen and hydrogen in the biomass. These patterns from NIRS are like a fingerprint of the sample. They help us identify and analyze the chemical structure of the sample'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of the sample from NIRS. Different biomass samples give us patterns from NIRS, based on what they are made of and how they are structured. To make this information from NIRS more useful we use'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='more useful we use techniques, like calibration models. These models help us turn the information from NIRS into values like the percentages of cellulose, hemicellulose and lignin in the sample from'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='in the sample from NIRS.  We often present this information from NIRS in tables so it is easy to compare samples from NIRS. We also use graphs and charts to show how the composition of the samples'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='of the samples varies and to identify trends from NIRS. Sometimes we use advanced data analysis methods, like multivariate analysis, to improve the accuracy of the results from NIRS and get'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='from NIRS and get information from the spectral data from NIRS. This helps us reduce noise and make the results from NIRS more reliable. The final result of the NIRS analysis includes both'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='includes both information, which gives us a clear understanding of the biomass structure from NIRS. This information from NIRS is useful for research, quality control and industrial applications.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='applications.  The way we present the information from NIRS is designed to be simple and clear. It is easy to understand and make decisions without having to do tests from NIRS. Overall NIRS gives us'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='NIRS gives us efficient information, which makes it a powerful tool for evaluating and comparing lignocellulosic biomass samples from NIRS. 3.8 Summary of Work Done The work we did in this an'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='we did in this an analysis about using Near-Infrared Spectroscopy or NIRS to study biomass. We did this work to see how NIRS can be used as a way to analyze biomass. We. Did the study in a way so we'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='in a way so we could get reliable results from NIRS. First we learned about biomass and what it is made of including cellulose, hemicellulose and lignin. We also learned about why biomasses important'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='biomasses important for bioenergy and industrial applications. We collected biomass samples from places and labeled them so we could use them for further analysis from NIRS. We made sure the samples'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='sure the samples were representative and not contaminated.  25 We then prepared the samples by drying and grinding them into a form. This was a step because it helped us get consistent and accurate'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and accurate readings when we did the NIRS analysis. We set up the NIR spectrometer. Calibrated it before we started the analysis from NIRS. This ensured that the results from NIRS were accurate and'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='were accurate and repeatable. We then analyzed each sample using NIRS.  We recorded the information from NIRS. The way the infrared radiation interacted with the biomass components gave us spectral'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='gave us spectral signatures for each sample from NIRS. We processed the information from NIRS. Presented it in graphs and tables. We used calibration models to turn the information from NIRS into'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='from NIRS into quantitative results like the composition of the biomass from NIRS. We studied the NIRS results to see how the different samples varied and to evaluate how well the technique from NIRS'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='technique from NIRS worked. Overall, this work shows that NIRS is a non-destructive way to assess lignocellulosic biomass, which makes it suitable for research and industrial applications, from NIRS.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='from NIRS. 26 CHAPTER – 4 RESULT AND DISCUSSION  27 4.RESULT AND DISCUSSION 4.1 Introduction The purpose of this section is to provide an analysis and discussion of the findings produced by the NIRS'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='by the NIRS sensor technology study conducted on lignocellulosic biomass. The main objective of this research is to assess the relationship between the changing composition of biomass (i.e., lignin,'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='(i.e., lignin, cellulose, and hemicellulose) over a period of time and its ability to degrade biologically. NIRS technology allows for a quick, non-destructive analysis of biomass in real time.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='in real time. Unlike the traditional laboratory method of testing, once the measurement has been taken, it is able to continually monitor and decrease the chances of excessive handling of the'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='handling of the samples, which ultimately leads to errors in measurements. The results discussed in this chapter will provide you with the information necessary to determine which types of biomass'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='types of biomass materials are compatible with a bioreactor and how they can perform optimally in a waste to energy system.  4.2 Experimental Setup Overview Biomass samples of Napier grasses were'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Napier grasses were used to conduct the experiment in the study. The experiment examined the structural composition of the stem and leaf portions separately to identify the differences. The natural'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='The natural decomposition of the biomass was measured by collecting the samples at three different time periods of 15, 30, and 60 days. The spectral data from the biomass samples were acquired using'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='were acquired using an AS726X NIRS Sensor. The light emitted from this sensor is in the near-IR range and is directed toward the biomass surface, then the reflected light or energy is analyzed for'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='is analyzed for chemical composition estimation. The relative levels of each chemical component (Lignin, 28 Cellulose and Hemicellulose) can be determined from the spectral data due to their unique'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='due to their unique absorption properties. The experimental set-up was specifically created to not cause any disturbances to the samples while being tested. While obtaining repeated measurements of'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='measurements of the same sample over time, the non-destructive method provided consistent results and ensured the reliability of the observed results.  4.3 Data Acquisition and Transmission The data'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='The data acquiring process included using the NIRS sensor to capture the reflectance values from the biomass samples. The data obtained from the spectral analysis was used to determine the percentage'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='the percentage of cellulose, hemicellulose, and lignin. To observe the variations in composition over time, the experiments were conducted at regular intervals of 15, 30, and 60 days. Collected data'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Collected data was recorded in a very organized manner to allow for ease of comparison of the different stages of degradation and different parts of the plant (stem and leaves).  The system allowed'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='The system allowed continuous and efficient data collection, improving to a much less approach than the observation of data by the human eye. The approach led to an increase in the accuracy and'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='in the accuracy and repeatability of results, which subsequently allowed for detecting even the smallest amount of change in the composition of the biomass. 4.4 Visualization and Dashboard Results'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Dashboard Results The experimental data collected using the NIRS sensor were arranged in tabular forms as well as represented graphically. A graphical method was very effective for analyzing the'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='for analyzing the results derived from experimentation because it enabled the identification of different trends. The graphs that were made based on lignin, cellulose, and hemicellulose'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and hemicellulose concentrations showed the variation among each other.  The values that were taken after 15, 30, and 60 days allowed us to understand the variation of biomass decomposition.'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='decomposition. Observations: Lignin content exhibited a rising 29 pattern. Cellulose content depicted a decreasing pattern. Variation pattern observed for hemicellulose. This form of graphical'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='form of graphical representation helped compare the performance of stems and leaves. 4.5 Result Interpretation The results generated through experimental analysis exhibit considerable variability in'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='variability in composition of lignocellulose present in biomass at various stages of growth. These factors affect the biodegradability and performance of biomass in bioreactors. Lignin content'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='Lignin content witnessed a steady increase in leaf and stem samples of biomass.  For leaf samples, there was an increase of 49.63% in lignin content between day 15 and 30, and an additional increase'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='additional increase of 48.51% from 30 to 60 days. In stem samples, there was an increase of 29.49% in lignin content during the first stage of experiment (15–30 days), and further increase by 59.41%'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='increase by 59.41% during the second stage of experiment (30–60 days). Thus, steady increase in lignin content implies that the biomass gets gradually more resistant to biodegradability due to higher'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='due to higher structural complexity. On the contrary, content of cellulose in leaf samples was found to decline. There was a decline of 4.67% in cellulose content between day 15 and 30 and a sharp'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='and 30 and a sharp decline of 30.34% from day 30 to 60. The result clearly suggests that cellulose undergoes active breakdown and consumption for energy by microbes. Content of hemicellulose was'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='hemicellulose was found to vary considerably in the two sample sets.In leaves, it decreased by 16.67% between Day 15 and Day 30, but later increased by 47.57% from Day 30 to Day 60. Similarly, in'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='60. Similarly, in stem samples, hemicellulose decreased by 27.33% in the initial phase and then increased by 25.23% in the later phase. This variation can be explained by the partial degradation of'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='degradation of hemicellulose in the early stage and its relative increase in proportion as cellulose content decreases. Overall, the results highlight that lignin acts as a limiting factor in'),
#  Document(metadata={'source': 'lignine.txt'}, page_content='limiting factor in biodegradation, while cellulose contributes positively to microbial activity. The variation of hemicellulose values indicates its transitional role in the degradation process')]

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
print(embeddings)
# Out:
# client=SentenceTransformer(
#   (0): Transformer({'transformer_task': 'feature-extraction', 'modality_config': {'text': {'method': 'forward', 'method_output_name': 'last_hidden_state'}}, 'module_output_name': 'token_embeddings', 'architecture': 'BertModel'})
#   (1): Pooling({'embedding_dimension': 384, 'pooling_mode': 'mean', 'include_prompt': True})
#   (2): Normalize({})
# ) model_name='sentence-transformers/all-MiniLM-L6-v2' cache_folder=None model_kwargs={} encode_kwargs={} multi_process=False show_progress=False

# %%
# vector Store in DB
# !pip install faiss-cpu
from langchain_community.vectorstores import FAISS
db = FAISS.from_documents(finalDocuments, embeddings)
db
print(db)
# Out:
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.12/dist-packages (1.14.3)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (26.2)
# <langchain_community.vectorstores.faiss.FAISS object at 0x7c8ec14088c0>

# %%
Query = input("Enter your question?: ")
docs = db.similarity_search(Query)
for i in range(len(docs)):
    print(docs[i].page_content)
# Out:
# Enter your question?: compare lignine content of a plant of age 15 days to that of 30 days
# additional increase of 48.51% from 30 to 60 days. In stem samples, there was an increase of 29.49% in lignin content during the first stage of experiment (15–30 days), and further increase by 59.41%
# Lignin content witnessed a steady increase in leaf and stem samples of biomass.  For leaf samples, there was an increase of 49.63% in lignin content between day 15 and 30, and an additional increase
# the percentage of cellulose, hemicellulose, and lignin. To observe the variations in composition over time, the experiments were conducted at regular intervals of 15, 30, and 60 days. Collected data
# increase by 59.41% during the second stage of experiment (30–60 days). Thus, steady increase in lignin content implies that the biomass gets gradually more resistant to biodegradability due to higher
